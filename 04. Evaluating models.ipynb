# %%
import pandas as pd
import glob

import numpy as np
results = pd.concat([pd.read_csv(f) for f in glob.glob('data/result*')], ignore_index=True)
results = results.groupby(["experiment", "hierarchy"]).agg(
    in_top_one=('in_top_one', "sum"), 
    in_top_three=('in_top_three', "sum"), 
    in_top_ten=('in_top_ten', "sum"), 
    n = ('in_top_ten', "count")
).reset_index()

results.in_top_one = results.in_top_one /
# Out:
#              experiment hierarchy  in_top_one  in_top_three  in_top_ten    n
# 0   sentence_similarity       F02           6            10          13   91
# 1   sentence_similarity       F03          32            75         176  500
# 2   sentence_similarity       F04           7            28          73  500
# 3   sentence_similarity       F06          37            86         114  177
# 4   sentence_similarity       F07          36            46          57  113
# 5   sentence_similarity       F08          27            39          75  125
# 6   sentence_similarity       F09          18            24          31  139
# 7   sentence_similarity       F10          34            83         249  500
# 8   sentence_similarity       F17          68           152         279  500
# 9   sentence_similarity       F18           8            18          48   70
# 10  sentence_similarity       F19          32           118         344  500
# 11  sentence_similarity       F20          64           166         302  500
# 12  sentence_similarity       F21          16            44         149  199
# 13  sentence_similarity       F22          49           142         416  500
# 14  sentence_similarity       F23          11            27          28   28
# 15  sentence_similarity       F24           0             8          79   94
# 16  sentence_similarity       F25          16            17          17   20
# 17  sentence_similarity       F26          52           378         378  500
# 18  sentence_similarity       F27          81           154         255  331
# 19  sentence_similarity       F28          70           137         200  500
# 20  sentence_similarity  baseterm          34            75         162  500
# 21  sentence_similarity    facets           0             0           0  500
