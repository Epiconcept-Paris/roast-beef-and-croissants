# %%
import pandas as pd
import glob

import numpy as np
results = pd.concat([pd.read_csv(f) for f in glob.glob('data/result*')], ignore_index=True)
results = results.groupby(["experiment", "hierarchy"]).agg(
    in_top_one=('in_top_one', "sum"), 
    in_top_three=('in_top_three', "sum"), 
    in_top_ten=('in_top_ten', "sum"), 
    n = ('in_top_ten', "count")
).reset_index()

results.in_top_one = results.in_top_one / results.n
results.in_top_three = results.in_top_three / results.n
results.in_top_ten = results.in_top_ten / results.n

results.sort_values(["hierarchy", "experiment"])
# Out:
#               experiment hierarchy  in_top_one  in_top_three  in_top_ten    n
# 0    sentence_similarity       F01    0.187500      0.468750    0.468750   32
# 1    sentence_similarity       F02    0.065934      0.109890    0.142857   91
# 2    sentence_similarity       F03    0.064000      0.150000    0.352000  500
# 28      zero_shot_simple       F03    0.344000      0.512000    0.608000  500
# 3    sentence_similarity       F04    0.014000      0.056000    0.146000  500
# 29      zero_shot_simple       F04    0.008000      0.028000    0.056000  500
# 4    sentence_similarity       F06    0.209040      0.485876    0.644068  177
# 5    sentence_similarity       F07    0.318584      0.407080    0.504425  113
# 6    sentence_similarity       F08    0.216000      0.312000    0.600000  125
# 7    sentence_similarity       F09    0.129496      0.172662    0.223022  139
# 30      zero_shot_simple       F09    0.093525      0.129496    0.223022  139
# 8    sentence_similarity       F10    0.068000      0.166000    0.498000  500
# 31      zero_shot_simple       F10    0.390000      0.510000    0.584000  500
# 9    sentence_similarity       F11    0.285714      0.428571    0.571429    7
# 10   sentence_similarity       F12    0.000000      0.000000    0.666667    3
# 11   sentence_similarity       F17    0.136000      0.304000    0.558000  500
# 12   sentence_similarity       F18    0.114286      0.257143    0.685714   70
# 13   sentence_similarity       F19    0.064000      0.236000    0.688000  500
# 14   sentence_similarity       F20    0.128000      0.332000    0.604000  500
# 15   sentence_similarity       F21    0.080402      0.221106    0.748744  199
# 32      zero_shot_simple       F21    0.195980      0.306533    0.437186  199
# 16   sentence_similarity       F22    0.098000      0.284000    0.832000  500
# 17   sentence_similarity       F23    0.392857      0.964286    1.000000   28
# 18   sentence_similarity       F24    0.000000      0.085106    0.840426   94
# 19   sentence_similarity       F25    0.800000      0.850000    0.850000   20
# 20   sentence_similarity       F26    0.104000      0.756000    0.756000  500
# 21   sentence_similarity       F27    0.244713      0.465257    0.770393  331
# 22   sentence_similarity       F28    0.140000      0.274000    0.400000  500
# 23   sentence_similarity       F31    0.000000      0.000000    0.333333    3
# 24   sentence_similarity       F33    0.000000      0.000000    0.200000    5
# 25   sentence_similarity  baseterm    0.068000      0.150000    0.324000  500
# 27  zero_shot_hypothesis  baseterm    0.018000      0.106000    0.266000  500
# 33      zero_shot_simple  baseterm    0.100000      0.188000    0.340000  500
# 26   sentence_similarity    facets    0.000000      0.000000    0.000000  500
# 34      zero_shot_simple    facets    0.000000      0.000000    0.000000  500
